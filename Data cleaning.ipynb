# %%
import pandas as pd

# %%
df = pd.read_csv("data-analisis-sentimen-terhadap-fenomena-vibecoding.csv")
df
# Out:
#                      Date                  Username  \
# 0    2025-11-24T01:13:15Z  @hendratmobudihardjo4405
# 1    2025-11-23T10:30:24Z        @TigaherangChannel
# 2    2025-11-23T02:05:51Z               @noertri618
# 3    2025-11-21T15:27:06Z        @kuliahkentang2146
# 4    2025-11-18T09:04:50Z              @nengmoemoen
# ..                    ...                       ...
# 402  2025-10-13T11:32:02Z        @muhammad.azqilana
# 403  2025-10-13T11:31:38Z          @parthawijaya482
# 404  2025-10-13T12:56:40Z         @sandhikagalihWPU
# 405  2025-10-13T11:30:57Z     @rofiaziztaufikrahmat
# 406  2025-10-13T11:30:48Z                 @apre-t5p
#
#                                                Comment  Like
# 0    Gak papa pak, biar saingan kita sebagai progra...     0
# 1    Dari sekian banyak AI, sejauh ini gw baru pake...     0
# 2    Gara-gara AI harga komponen-komponen pc naik g...     0
# 3    Kalo pas skripsi belom bisa coding, mau beli p...     0
# 4    Saya punya pengalaman, d kantor sayaadassorang...     0
# ..                                                 ...   ...
# 402  Ini yg aku tunggu terimakasih pak pengajaran d...     1
# 403  Ijin menambahkan Pak Sandhika, vibe coder itu ...     0
# 404  nice share. yang jago makin jago, yang ngecit ...     0
# 405                                              First     0
# 406                                      pertama pakkk     0
#
# [407 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 407 entries, 0 to 406
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      407 non-null    object
#  1   Username  406 non-null    object
#  2   Comment   407 non-null    object
#  3   Like      407 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 12.8+ KB

# %%
df.columns
# Out:
# Index(['Date', 'Username', 'Comment', 'Like'], dtype='object')

# %%
df.describe()
# Out:
#              Like
# count  407.000000
# mean     1.894349
# std     12.416069
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      0.000000
# max    191.000000

# %%
print(f"""jumlah kolom : {len(df.columns)} yaitu --> {df.columns}
""")
# Out:
# jumlah kolom : 4 yaitu --> Index(['Date', 'Username', 'Comment', 'Like'], dtype='object')

# %%
print(f"""jumlah missing value : 
{df.isnull().sum()}""")
# Out:
# jumlah missing value :
# Date        0
# Username    1
# Comment     0
# Like        0
# dtype: int64

# %%
df["Username"] = df["Username"].fillna("unknown")

# %%
df.isnull().sum()
# Out:
# Date        0
# Username    0
# Comment     0
# Like        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df
